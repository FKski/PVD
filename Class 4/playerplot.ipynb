# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#plt.plot(["Novak Djokovic","Rafael Nadal","Roger Federer","Pete Sampras"],[24,22,20,14])
#plt.xlabel("Player")

playerSeries = pd.Series([24,22,20,14])
playerSeries.index=["Novak Djokovic","Rafael Nadal","Roger Federer","Pete Sampras"]
playerSeries.plot(xlabel="Player",ylabel="Title count",title=" Grand Slam tournament title count for players")
# Out:
# <Axes: title={'center': ' Grand Slam tournament title count for players'}, xlabel='Player', ylabel='Title count'>
